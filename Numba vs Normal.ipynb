# %%
from Bitcoin_MonteCarlo import Timeseries_MonteCarlo
from Bitcoin_MonteCarlo_Numba import Timeseries_MonteCarlo as Timeseries_Numba

trading_days = 365
horizon = 365
model = 'Returns'
simulations = 100
risk_free_rate = .03
ticker = 'BTC-USD'
period = 'max' # Can also have a start/end data,  dict(start='2000-01-01',end='2015-01-01')

# If choosing to evaluate options
options_info = dict(options_type='Asian', strike_price='geometric', call=True, contract_price = 5, interval=4) # Only necessary if model='Options', can be European or Asian.

# This shows some potential in building a relevant series
arch_garch = dict(vol='GARCH', p=1, q=1, o=0, mean="Zero", rescale=True, dist='normal') # These are default values, can be changed
arima = dict(information_criterion='bic') # These are default values, can be changed

TS = Timeseries_MonteCarlo(ticker=ticker, period=period, model=model, horizon=horizon, trading_days=trading_days, options_info=options_info, risk_free_rate=risk_free_rate, arima=arima,arch_garch=arch_garch)
TS.run_simulation(simulations)
TS.simulation_statistics()
# Out:
# C:\Users\G_MAN\anaconda3\envs\data_science\lib\site-packages\statsmodels\tsa\base\tsa_model.py:7: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import (to_datetime, Int64Index, DatetimeIndex, Period,
# C:\Users\G_MAN\anaconda3\envs\data_science\lib\site-packages\statsmodels\tsa\base\tsa_model.py:7: FutureWarning: pandas.Float64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import (to_datetime, Int64Index, DatetimeIndex, Period,
# Beginning Simulations...
# Completed Simulation # 1
# Completed Simulation # 2
# Completed Simulation # 3
# Completed Simulation # 4
# Completed Simulation # 5
# Completed Simulation # 6
# Completed Simulation # 7
# Completed Simulation # 8
# Completed Simulation # 9
# Completed Simulation # 10
# Completed Simulation # 11
# Completed Simulation # 12
# Completed Simulation # 13
# Completed Simulation # 14
# Completed Simulation # 15
# Completed Simulation # 16
# Completed Simulation # 17
# Completed Simulation # 18
# Completed Simulation # 19
# Completed Simulation # 20
# Completed Simulation # 21
# Completed Simulation # 22
# Completed Simulation # 23
# Completed Simulation # 24
# Completed Simulation # 25
# Completed Simulation # 26
# Completed Simulation # 27
# Completed Simulation # 28
# Completed Simulation # 29
# Completed Simulation # 30
# Completed Simulation # 31
# Completed Simulation # 32
# Completed Simulation # 33
# Completed Simulation # 34
# Completed Simulation # 35
# Completed Simulation # 36
# Completed Simulation # 37
# Completed Simulation # 38
# Completed Simulation # 39
# Completed Simulation # 40
# Completed Simulation # 41
# Completed Simulation # 42
# Completed Simulation # 43
# Completed Simulation # 44
# Completed Simulation # 45
# Completed Simulation # 46
# Completed Simulation # 47
# Completed Simulation # 48
# Completed Simulation # 49
# Completed Simulation # 50
# Completed Simulation # 51
# Completed Simulation # 52
# Completed Simulation # 53
# Completed Simulation # 54
# Completed Simulation # 55
# Completed Simulation # 56
# Completed Simulation # 57
# Completed Simulation # 58
# Completed Simulation # 59
# Completed Simulation # 60
# Completed Simulation # 61
# Completed Simulation # 62
# Completed Simulation # 63
# Completed Simulation # 64
# Completed Simulation # 65
# Completed Simulation # 66
# Completed Simulation # 67
# Completed Simulation # 68
# Completed Simulation # 69
# Completed Simulation # 70
# Completed Simulation # 71
# Completed Simulation # 72
# Completed Simulation # 73
# Completed Simulation # 74
# Completed Simulation # 75
# Completed Simulation # 76
# Completed Simulation # 77
# Completed Simulation # 78
# Completed Simulation # 79
# Completed Simulation # 80
# Completed Simulation # 81
# Completed Simulation # 82
# Completed Simulation # 83
# Completed Simulation # 84
# Completed Simulation # 85
# Completed Simulation # 86
# Completed Simulation # 87
# Completed Simulation # 88
# Completed Simulation # 89
# Completed Simulation # 90
# Completed Simulation # 91
# Completed Simulation # 92
# Completed Simulation # 93
# Completed Simulation # 94
# Completed Simulation # 95
# Completed Simulation # 96
# Completed Simulation # 97
# Completed Simulation # 98
# Completed Simulation # 99
# Completed Simulation # 100
#
# 100 Simulation(s) Completed in 0 hour(s), 0 minute(s), and 29.81 second(s)
# ---------------------------------------------------------------------------
# Reviewing 7 year(s), 6 month(s), and 0 day(s) of historical data
# Average Profit/Loss: $-1,392.51
# Profit/Loss Ranges from $-33,312.08 - $14,960.72
# Probability of Earning a Return = 52.00%
# The VaR at 95% Confidence is: $-20,508.86
# ---------------------------------------------------------------------------

# %%
TS = Timeseries_Numba(ticker=ticker, period=period, model=model, horizon=horizon, trading_days=trading_days,
                           options_info=options_info, risk_free_rate=risk_free_rate, arima=arima, arch_garch=arch_garch)
TS.run_simulation(simulations)
# Out:
# Beginning Simulations...
# Completed Simulation # 1
# Completed Simulation # 2
# Completed Simulation # 3
# Completed Simulation # 4
# Completed Simulation # 5
# Completed Simulation # 6
# Completed Simulation # 7
# Completed Simulation # 8
# Completed Simulation # 9
# Completed Simulation # 10
# Completed Simulation # 11
# Completed Simulation # 12
# Completed Simulation # 13
# Completed Simulation # 14
# Completed Simulation # 15
# Completed Simulation # 16
# Completed Simulation # 17
# Completed Simulation # 18
# Completed Simulation # 19
# Completed Simulation # 20
# Completed Simulation # 21
# Completed Simulation # 22
# Completed Simulation # 23
# Completed Simulation # 24
# Completed Simulation # 25
# Completed Simulation # 26
# Completed Simulation # 27
# Completed Simulation # 28
# Completed Simulation # 29
# Completed Simulation # 30
# Completed Simulation # 31
# Completed Simulation # 32
# Completed Simulation # 33
# Completed Simulation # 34
# Completed Simulation # 35
# Completed Simulation # 36
# Completed Simulation # 37
# Completed Simulation # 38
# Completed Simulation # 39
# Completed Simulation # 40
# Completed Simulation # 41
# Completed Simulation # 42
# Completed Simulation # 43
# Completed Simulation # 44
# Completed Simulation # 45
# Completed Simulation # 46
# Completed Simulation # 47
# Completed Simulation # 48
# Completed Simulation # 49
# Completed Simulation # 50
# Completed Simulation # 51
# Completed Simulation # 52
# Completed Simulation # 53
# Completed Simulation # 54
# Completed Simulation # 55
# Completed Simulation # 56
# Completed Simulation # 57
# Completed Simulation # 58
# Completed Simulation # 59
# Completed Simulation # 60
# Completed Simulation # 61
# Completed Simulation # 62
# Completed Simulation # 63
# Completed Simulation # 64
# Completed Simulation # 65
# Completed Simulation # 66
# Completed Simulation # 67
# Completed Simulation # 68
# Completed Simulation # 69
# Completed Simulation # 70
# Completed Simulation # 71
# Completed Simulation # 72
# Completed Simulation # 73
# Completed Simulation # 74
# Completed Simulation # 75
# Completed Simulation # 76
# Completed Simulation # 77
# Completed Simulation # 78
# Completed Simulation # 79
# Completed Simulation # 80
# Completed Simulation # 81
# Completed Simulation # 82
# Completed Simulation # 83
# Completed Simulation # 84
# Completed Simulation # 85
# Completed Simulation # 86
# Completed Simulation # 87
# Completed Simulation # 88
# Completed Simulation # 89
# Completed Simulation # 90
# Completed Simulation # 91
# Completed Simulation # 92
# Completed Simulation # 93
# Completed Simulation # 94
# Completed Simulation # 95
# Completed Simulation # 96
# Completed Simulation # 97
# Completed Simulation # 98
# Completed Simulation # 99
# Completed Simulation # 100
# -715.8561475903721

# %%
TS.simulation_statistics(plot_simulated=3)
# Out:
# 100 Simulation(s) Completed in 0 hour(s), 0 minute(s), and 0.19 second(s)
# --------------------------------------------------------------------------
# Reviewing 7 year(s), 6 month(s), and 0 day(s) of historical data
# Average Profit/Loss: $-715.86
# Profit/Loss Ranges from $-30,333.80 - $17,343.61
# Probability of Earning a Return = 47.00%
# The VaR at 95% Confidence is: $-18,258.69
# --------------------------------------------------------------------------
