# %% [raw]
# # Modeling Returns

# %%
trading_days = 365
horizon = 365
risk_free_rate = .03
ticker = 'BTC-USD'
period = 'max'  # Can also have a start/end data,  dict(start='2000-01-01',end='2015-01-01')

# Configure ARMA-GARCH
arch_garch = dict(vol='GARCH', p=1, q=1, o=0, mean="Zero", rescale=True,
                  dist='normal')  # These are default values, can be changed
arima = dict(information_criterion='bic')  # These are default values, can be changed

# %% [raw]
# ## Using Numba

# %%
from modules.monte_carlo import Timeseries_MonteCarlo
numba = True  # True if you wish to leverage numba, False if not
simulations = 100000
model = 'Returns'  # 'Returns'/'Options'
options_info = None

ts_1 = Timeseries_MonteCarlo(ticker=ticker, period=period, model=model, horizon=horizon,
                             trading_days=trading_days,
                             options_info=options_info, risk_free_rate=risk_free_rate, arima=arima,
                             arch_garch=arch_garch, numba=numba)
ts_1.run_simulation(simulations)
ts_1.save('../results')
# Out:
# C:\Users\G_MAN\anaconda3\envs\data_science\lib\site-packages\statsmodels\tsa\base\tsa_model.py:7: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import (to_datetime, Int64Index, DatetimeIndex, Period,
# C:\Users\G_MAN\anaconda3\envs\data_science\lib\site-packages\statsmodels\tsa\base\tsa_model.py:7: FutureWarning: pandas.Float64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import (to_datetime, Int64Index, DatetimeIndex, Period,
# Beginning Simulations...
# Completed Simulation # 0
# Completed Simulation # 10,000
# Completed Simulation # 20,000
# Completed Simulation # 30,000
# Completed Simulation # 40,000
# Completed Simulation # 50,000
# Completed Simulation # 60,000
# Completed Simulation # 70,000
# Completed Simulation # 80,000
# Completed Simulation # 90,000
# Completed Simulation # 100,000

# %%
ts_1.simulation_statistics(plot_simulated=3)
# Out:
# 100,000 Simulation(s) Completed in 0 hour(s), 2 minute(s), and 45.90 second(s)
# -------------------------------------------------------------------------------
# Reviewing 7 year(s), 6 month(s), and 5 day(s) of historical data
# Average Profit/Loss: $-1,247.63
# Profit/Loss Ranges from $-69,557.62 - $24,498.16
# 95% Confidence Interval Range: from $-1,304.82 - $-1,190.44
# Probability of Earning a Return = 48.78%
# The VaR at 95% Confidence is: $-17,794.46
# -------------------------------------------------------------------------------

# %% [raw]
# ## Without using Numba

# %%
numba = False
simulations = 100

ts_2 = Timeseries_MonteCarlo(ticker=ticker, period=period, model=model, horizon=horizon,
                             trading_days=trading_days,
                             options_info=options_info, risk_free_rate=risk_free_rate, arima=arima,
                             arch_garch=arch_garch, numba=numba)
ts_2.run_simulation(simulations)

ts_2.save('../results')
# Out:
# Beginning Simulations...
# Completed Simulation # 0
# Completed Simulation # 10
# Completed Simulation # 20
# Completed Simulation # 30
# Completed Simulation # 40
# Completed Simulation # 50
# Completed Simulation # 60
# Completed Simulation # 70
# Completed Simulation # 80
# Completed Simulation # 90
# Completed Simulation # 100

# %%
ts_2.simulation_statistics(plot_simulated=6)
# Out:
# 100 Simulation(s) Completed in 0 hour(s), 0 minute(s), and 31.09 second(s)
# ---------------------------------------------------------------------------
# Reviewing 7 year(s), 6 month(s), and 5 day(s) of historical data
# Average Profit/Loss: $-528.23
# Profit/Loss Ranges from $-22,561.05 - $18,576.28
# 95% Confidence Interval Range: from $-2,193.57 - $1,137.12
# Probability of Earning a Return = 53.00%
# The VaR at 95% Confidence is: $-14,915.55
# ---------------------------------------------------------------------------

# %% [raw]
# # Modeling Options
# ## Using Numba

# %%
numba = True
model = 'Options'
simulations = 100000
options_info = dict(options_type='Asian', strike_price='geometric', call=True, contract_price=5,
                    interval=4)  # Only necessary if model='Options', can be European or Asian.

ts_3 = Timeseries_MonteCarlo(ticker=ticker, period=period, model=model, horizon=horizon,
                             trading_days=trading_days,
                             options_info=options_info, risk_free_rate=risk_free_rate, arima=arima,
                             arch_garch=arch_garch, numba=numba)
ts_3.run_simulation(simulations)
ts_3.save('../results')
# Out:
# Beginning Simulations...
# Completed Simulation # 0
# Completed Simulation # 10,000
# Completed Simulation # 20,000
# Completed Simulation # 30,000
# Completed Simulation # 40,000
# Completed Simulation # 50,000
# Completed Simulation # 60,000
# Completed Simulation # 70,000
# Completed Simulation # 80,000
# Completed Simulation # 90,000
# Completed Simulation # 100,000

# %%
ts_3.simulation_statistics(plot_simulated=3)
# Out:
# 100,000 Simulation(s) Completed in 0 hour(s), 6 minute(s), and 45.18 second(s)
# -------------------------------------------------------------------------------
# Reviewing 7 year(s), 6 month(s), and 5 day(s) of historical data
# Average Profit/Loss: $2,415.58
# Profit/Loss Ranges from $-5.00 - $37,772.08
# 95% Confidence Interval Range: from $2,392.33 - $2,438.82
# Probability of Earning a Return = 51.21%
# The VaR at 95% Confidence is: $-5.00
# -------------------------------------------------------------------------------

# %% [raw]
# ## Without using Numba

# %%
numba = False
simulations = 100

ts_4 = Timeseries_MonteCarlo(ticker=ticker, period=period, model=model, horizon=horizon,
                             trading_days=trading_days,
                             options_info=options_info, risk_free_rate=risk_free_rate, arima=arima,
                             arch_garch=arch_garch, numba=numba)
ts_4.run_simulation(simulations)
ts_4.save('../results')
# Out:
# Beginning Simulations...
# Completed Simulation # 0
# Completed Simulation # 10
# Completed Simulation # 20
# Completed Simulation # 30
# Completed Simulation # 40
# Completed Simulation # 50
# Completed Simulation # 60
# Completed Simulation # 70
# Completed Simulation # 80
# Completed Simulation # 90
# Completed Simulation # 100

# %%
ts_4.simulation_statistics(plot_simulated=0)
# Out:
# 100 Simulation(s) Completed in 0 hour(s), 0 minute(s), and 31.22 second(s)
# ---------------------------------------------------------------------------
# Reviewing 7 year(s), 6 month(s), and 5 day(s) of historical data
# Average Profit/Loss: $2,464.37
# Profit/Loss Ranges from $-5.00 - $18,938.18
# 95% Confidence Interval Range: from $1,750.71 - $3,178.03
# Probability of Earning a Return = 54.00%
# The VaR at 95% Confidence is: $-5.00
# ---------------------------------------------------------------------------
